# %% [markdown]
# # Calculando valores. Operadores y expresiones

# %% [markdown]
# Operadodes sobre **int** y **float**:
#
# suma: +
#
# resta: -
#
# multiplicacion: *
#
# division: /
#
# inverso aditivo: -
#
# exponenciacion: **
#
# division entera: //
#
# modulo: %
#
# menor: <
#
# mayor o igual: >=
#
# distinto: !=
#
# igualdad: ==

# %%
#suma
7+5
# Out:
# 12

# %%
#resta
7-5
# Out:
# 2

# %%
#multiplicacion
7*5
# Out:
# 35

# %%
#division
7/5
# Out:
# 1.4

# %%
#inverso aditivo
-5
# Out:
# -5

# %%
#exponenciacion
7**5
# Out:
# 16807

# %%
#division entera
7//5
# Out:
# 1

# %%
#modulo
7%5
# Out:
# 2

# %%
#menor
5<5.1
# Out:
# True

# %%
#mayor o igual
3>=5
# Out:
# False

# %%
#distinto
3!=5
# Out:
# True

# %%
#igualdad 
6==9
# Out:
# False

# %% [markdown]
# Se aplican a **bool**
#
# not
#
# and
#
# or

# %%
#not
not 3>5

# %%
#and
3>5 and 2<6

# %%
#disyuncion logica(O)
3>5 or 2<6

# %% [markdown]
# Operadores para **str**
#
# concatenacion +
#
# repeticion *

# %%
#concatenacion
"Yo soy"+"tu padre"
# Out:
# 'Yo soytu padre'

# %%
"Ja"*4
# Out:
# 'JaJaJaJa'
