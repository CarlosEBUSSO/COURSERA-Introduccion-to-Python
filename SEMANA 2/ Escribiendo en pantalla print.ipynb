# %% [markdown]
# # Escribiendo en pantalla. print.

# %%
pesos_por_hora = 200
llegada = 20
salida = 22
precio = (salida-llegada)*pesos_por_hora
print(precio)
# Out:
# 400

# %%
mensaje="Hola mundo"
print(mensaje)
# Out:
# Hola mundo

# %%
episodio=3
print("Episodio",episodio,"del libro")
# Out:
# Episodio 3 del libro

# %% [markdown]
# carmbiar el termino de linea

# %%
nombre = "Cristian"
edad=38
print("Soy",nombre, end="")
print("y tengo", edad, "años")
print("cumplidos")
# Out:
# Soy Cristiany tengo 38 años
# cumplidos

# %%
msj1 = "Hoy habrá"
temp = 34
msj2 = "grados"
print(msj1,temp,msj2)
# Out:
# Hoy habrá 34 grados

# %% [markdown]
# cambiar el separador de expresiones

# %%
print("-El tesoro","esta","en",sep="...")
# Out:
# -el tesoro...esta...en
